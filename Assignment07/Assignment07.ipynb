# %% [markdown]
# <a href="https://colab.research.google.com/github/saketh105/Data690/blob/main/Assignment07/Assignment07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df= pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/assignments/assignment_07_world_dev/world_devlopment_indicator.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year        value          indicator Country Code Country Name  \
# 0           0  2002   876.327643  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 1           1  2003   928.191569  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 2           2  2004   925.704226  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 3           3  2005  1023.549501  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 4           4  2006  1078.907370  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
#
#        Region Income Group Lending Type
# 0  South Asia   Low income          IDA
# 1  South Asia   Low income          IDA
# 2  South Asia   Low income          IDA
# 3  South Asia   Low income          IDA
# 4  South Asia   Low income          IDA

# %%
df['Country Code'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW', 'AUS',
#        'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ',
#        'BEN', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA', 'BRN', 'BGR',
#        'BFA', 'BDI', 'CPV', 'KHM', 'CMR', 'CAN', 'CYM', 'CAF', 'TCD',
#        'CHL', 'CHN', 'COL', 'COM', 'COD', 'COG', 'CRI', 'CIV', 'HRV',
#        'CUW', 'CYP', 'CZE', 'DNK', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY',
#        'SLV', 'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'FJI', 'FIN', 'FRA',
#        'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GRD', 'GTM', 'GIN',
#        'GNB', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN',
#        'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR', 'KAZ',
#        'KEN', 'KIR', 'KOR', 'XKX', 'KWT', 'KGZ', 'LAO', 'LVA', 'LBN',
#        'LSO', 'LBR', 'LBY', 'LTU', 'LUX', 'MAC', 'MDG', 'MWI', 'MYS',
#        'MDV', 'MLI', 'MLT', 'MHL', 'MRT', 'MUS', 'MEX', 'FSM', 'MDA',
# ...

# %%
my_countries = ["PHL", "AFG", "JPN","TUR","VCT"]

df1 =df[df["Country Code"].isin(my_countries)]

df1.shape
# Out:
# (862, 9)

# %%
df1["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Japan', 'Philippines',
#        'St. Vincent and the Grenadines', 'Turkiye'], dtype=object)

# %%
df1.head()
# Out:
#    Unnamed: 0  Year        value          indicator Country Code Country Name  \
# 0           0  2002   876.327643  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 1           1  2003   928.191569  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 2           2  2004   925.704226  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 3           3  2005  1023.549501  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
# 4           4  2006  1078.907370  NY.GDP.PCAP.PP.CD          AFG  Afghanistan
#
#        Region Income Group Lending Type
# 0  South Asia   Low income          IDA
# 1  South Asia   Low income          IDA
# 2  South Asia   Low income          IDA
# 3  South Asia   Low income          IDA
# 4  South Asia   Low income          IDA

# %%
df1["indicator"].unique()
# Out:
# array(['NY.GDP.PCAP.PP.CD', 'SH.STA.SUIC.P5', 'SP.DYN.LE00.IN',
#        'SP.POP.TOTL'], dtype=object)

# %% [markdown]
# You must pick one indicator out of the four: population, life expectancy, GDP per capita, or suiside rate

# %%
le=df1.loc[df1['indicator']=='SP.DYN.LE00.IN']
le.head()
# Out:
#       Unnamed: 0  Year   value       indicator Country Code Country Name  \
# 9613        9613  1960  32.446  SP.DYN.LE00.IN          AFG  Afghanistan
# 9614        9614  1961  32.962  SP.DYN.LE00.IN          AFG  Afghanistan
# 9615        9615  1962  33.471  SP.DYN.LE00.IN          AFG  Afghanistan
# 9616        9616  1963  33.971  SP.DYN.LE00.IN          AFG  Afghanistan
# 9617        9617  1964  34.463  SP.DYN.LE00.IN          AFG  Afghanistan
#
#           Region Income Group Lending Type
# 9613  South Asia   Low income          IDA
# 9614  South Asia   Low income          IDA
# 9615  South Asia   Low income          IDA
# 9616  South Asia   Low income          IDA
# 9617  South Asia   Low income          IDA

# %%
le['Year'].max()
# Out:
# 2020

# %%
df2 = df1.query('indicator == "SP.DYN.LE00.IN" and Year == 2020')

df2
# Out:
#        Unnamed: 0  Year     value       indicator Country Code  \
# 9673         9673  2020  65.17300  SP.DYN.LE00.IN          AFG
# 15100       15100  2020  84.61561  SP.DYN.LE00.IN          JPN
# 18224       18224  2020  71.36000  SP.DYN.LE00.IN          PHL
# 19742       19742  2020  72.65800  SP.DYN.LE00.IN          VCT
# 20596       20596  2020  77.92800  SP.DYN.LE00.IN          TUR
#
#                          Country Name                      Region  \
# 9673                      Afghanistan                  South Asia
# 15100                           Japan         East Asia & Pacific
# 18224                     Philippines         East Asia & Pacific
# 19742  St. Vincent and the Grenadines  Latin America & Caribbean
# 20596                         Turkiye       Europe & Central Asia
#
#               Income Group    Lending Type
# 9673            Low income             IDA
# 15100          High income  Not classified
# 18224  Lower middle income            IBRD
# ...

# %%
fig = px.bar(df2, x="Country Name",  y="value", title="2020 Life expectancy of Afghanistan,Japan, Philippines,St. Vincent and the Grenadines, Turkiye",  color="Country Name")

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df2, names="Country Name",values="value",title="2020 Life expectancy of 'Afghanistan', 'Japan', 'Philippines','St. Vincent and the Grenadines', 'Turkiye'",color="Country Name",template="plotly_dark")

fig.update_layout(showlegend=True)

fig.update_traces(textposition='inside', textinfo='label+percent+value')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3= df1.query('indicator == "SP.DYN.LE00.IN"')

df3.head()
# Out:
#       Unnamed: 0  Year   value       indicator Country Code Country Name  \
# 9613        9613  1960  32.446  SP.DYN.LE00.IN          AFG  Afghanistan
# 9614        9614  1961  32.962  SP.DYN.LE00.IN          AFG  Afghanistan
# 9615        9615  1962  33.471  SP.DYN.LE00.IN          AFG  Afghanistan
# 9616        9616  1963  33.971  SP.DYN.LE00.IN          AFG  Afghanistan
# 9617        9617  1964  34.463  SP.DYN.LE00.IN          AFG  Afghanistan
#
#           Region Income Group Lending Type
# 9613  South Asia   Low income          IDA
# 9614  South Asia   Low income          IDA
# 9615  South Asia   Low income          IDA
# 9616  South Asia   Low income          IDA
# 9617  South Asia   Low income          IDA

# %% [markdown]
# Comparing all years using line chart

# %%
fig = px.line(df3,x="Year",y="value", title="2020 Life expectancy of Afghanistan, Japan, Philippines,St. Vincent and the Grenadines, Turkey",  color="Country Name", )

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(df3,x='Country Name',y='value', color='Country Name',title="2020 Life expectancy of 'Afghanistan', 'Japan', 'Philippines','St. Vincent and the Grenadines','Turkiye'")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["indicator"].unique()
# Out:
# array(['NY.GDP.PCAP.PP.CD', 'SH.STA.SUIC.P5', 'SP.DYN.LE00.IN',
#        'SP.POP.TOTL'], dtype=object)

# %% [markdown]
# ## You must compare all regions to see how they differ in the indicator
#
# * Compare one year (pick the latest year) using bar chart, pie chartList item

# %%
le1 =df.loc[df['indicator']=='SP.DYN.LE00.IN']
le1.head()
# Out:
#       Unnamed: 0  Year   value       indicator Country Code Country Name  \
# 9613        9613  1960  32.446  SP.DYN.LE00.IN          AFG  Afghanistan
# 9614        9614  1961  32.962  SP.DYN.LE00.IN          AFG  Afghanistan
# 9615        9615  1962  33.471  SP.DYN.LE00.IN          AFG  Afghanistan
# 9616        9616  1963  33.971  SP.DYN.LE00.IN          AFG  Afghanistan
# 9617        9617  1964  34.463  SP.DYN.LE00.IN          AFG  Afghanistan
#
#           Region Income Group Lending Type
# 9613  South Asia   Low income          IDA
# 9614  South Asia   Low income          IDA
# 9615  South Asia   Low income          IDA
# 9616  South Asia   Low income          IDA
# 9617  South Asia   Low income          IDA

# %%
life = le1.loc[le1['Year'] == 2020]
life
# Out:
#        Unnamed: 0  Year      value       indicator Country Code  \
# 9673         9673  2020  65.173000  SP.DYN.LE00.IN          AFG
# 9734         9734  2020  78.686000  SP.DYN.LE00.IN          ALB
# 9795         9795  2020  77.063000  SP.DYN.LE00.IN          DZA
# 9856         9856  2020  61.487000  SP.DYN.LE00.IN          AGO
# 9917         9917  2020  77.146000  SP.DYN.LE00.IN          ATG
# ...           ...   ...        ...             ...          ...
# 21328       21328  2020  79.819512  SP.DYN.LE00.IN          VIR
# 21359       21359  2020  74.213000  SP.DYN.LE00.IN          PSE
# 21420       21420  2020  66.181000  SP.DYN.LE00.IN          YEM
# 21481       21481  2020  64.194000  SP.DYN.LE00.IN          ZMB
# 21542       21542  2020  61.738000  SP.DYN.LE00.IN          ZWE
#
#                 Country Name                      Region         Income Group  \
# 9673             Afghanistan                  South Asia           Low income
# ...

# %%
df4 = life.groupby('Region')['value'].mean()
df4
# Out:
# Region
# East Asia & Pacific           74.940949
# Europe & Central Asia         77.607477
# Latin America & Caribbean     75.549769
# Middle East & North Africa    75.671365
# North America                 80.361789
# South Asia                    71.856875
# Sub-Saharan Africa            63.282555
# Name: value, dtype: float64

# %%
fig=px.bar(df4,x=df4.index,y='value', color=f5.index,title="2020 Life expectancy of 'Afghanistan', 'Japan', 'Philippines','St. Vincent and the Grenadines','Turkiye'")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df4, values='value', names=df4.index, title="2020 Life expectancy of 'Afghanistan', 'Japan', 'Philippines','St. Vincent and the Grenadines','Turkiye'")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Compare all Yers using Line Chart

# %%
mean_le1=le1.groupby(['Region','Year'])['value'].mean()
mean_le1=mean_le1.reset_index()

# %%
fig=px.line(mean_le1,x='Year',y='value',color='Region',title="'2020 Life expectancy of 'Afghanistan', 'Japan', 'Philippines','St. Vincent and the Grenadines','Turkiye'")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Use all countries, and pick year 2020, make a scatter plot with x being GDP per Capita and y being Life Expentancy. This plot will tell you the relationship between wealth and health.

# %%
df=df.loc[df['Year']==2020]
df.head()
# Out:
#      Unnamed: 0  Year         value          indicator Country Code  \
# 18           18  2020   2078.479082  NY.GDP.PCAP.PP.CD          AFG
# 49           49  2020  13632.186537  NY.GDP.PCAP.PP.CD          ALB
# 81           81  2020  11323.312219  NY.GDP.PCAP.PP.CD          DZA
# 113         113  2020   6478.332182  NY.GDP.PCAP.PP.CD          AGO
# 145         145  2020  18240.380406  NY.GDP.PCAP.PP.CD          ATG
#
#             Country Name                      Region         Income Group  \
# 18           Afghanistan                  South Asia           Low income
# 49               Albania       Europe & Central Asia  Upper middle income
# 81               Algeria  Middle East & North Africa  Lower middle income
# 113               Angola         Sub-Saharan Africa   Lower middle income
# 145  Antigua and Barbuda  Latin America & Caribbean           High income
#
#     Lending Type
# 18           IDA
# 49          IBRD
# 81          IBRD
# 113         IBRD
# 145         IBRD

# %%
indicators = ["SP.DYN.LE00.IN", "NY.GDP.PCAP.PP.CD"]

df5 = df[df["indicator"].isin(indicators)]

df5.shape
# Out:
# (391, 9)

# %%
gdp1 = pd.pivot_table(df, values = 'value', index='Country Name', columns = 'indicator').reset_index()
gdp1
# Out:
# indicator           Country Name  NY.GDP.PCAP.PP.CD  SP.DYN.LE00.IN  \
# 0                    Afghanistan        2078.479082       65.173000
# 1                        Albania       13632.186537       78.686000
# 2                        Algeria       11323.312219       77.063000
# 3                 American Samoa                NaN             NaN
# 4                        Andorra                NaN             NaN
# ..                           ...                ...             ...
# 212        Virgin Islands (U.S.)                NaN       79.819512
# 213           West Bank and Gaza        5698.412057       74.213000
# 214                  Yemen, Rep.                NaN       66.181000
# 215                       Zambia        3457.328102       64.194000
# 216                     Zimbabwe        2251.455674       61.738000
#
# indicator  SP.POP.TOTL
# 0           38928341.0
# 1            2837849.0
# 2           43851043.0
# 3              55197.0
# 4              77265.0
# ...

# %%
px.scatter(gdp1,x='NY.GDP.PCAP.PP.CD',y='SP.DYN.LE00.IN',color=gdp1.index)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
