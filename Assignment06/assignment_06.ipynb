# %% [markdown]
# <a href="https://colab.research.google.com/github/saketh105/Data690/blob/main/Assignment06/assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 06
# ### Note:
# - For visualization, you should use Plotly Express
# - Use this notebook as your template and follow the instructions
#
# The first half of this assignment is similar to assignment 04.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# The links to the zip file is:
#
# - https://collegescorecard.ed.gov/data (This web page contains the link to the zip file)
#
# - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip (The link to the zip file)
#
# You can run `!wget` command in Colab notebook to retrieve it directly, then run `!unzip` command to extract files (I have provided the cells to do so next for your convenience)
#
# Your folder structure should look like this in your Colab enviroment:
#
# - ...
# - 'MERGED1996_97_PP.csv',
# - 'MERGED2015_16_PP.csv',
# - ...
# - 'MERGED2017_18_PP.csv'
# - ...
#
# **Note: you should refresh the folder to see all files.**

# %% [markdown]
# ## Step 1 - Retrieve the zip file

# %%
# !wget https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip
# Out:
# --2022-10-20 23:28:17--  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip
# Resolving ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)... 3.30.49.38, 15.200.7.180, 2600:1f12:18a:7d01:f1e1:9eba:e165:68c6, ...
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|3.30.49.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 410294884 (391M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data_09012022.zip’
#
# CollegeScorecard_Ra  12%[=>                  ]  50.67M  24.9MB/s    in 2.0s
#
# 2022-10-20 23:28:20 (24.9 MB/s) - Connection closed at byte 53128788. Retrying.
#
# --2022-10-20 23:28:21--  (try: 2)  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|3.30.49.38|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 410294884 (391M), 357166096 (341M) remaining [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data_09012022.zip’
#
# CollegeScorecard_Ra 100%[++=================>] 391.29M  36.4MB/s    in 10s
#
# 2022-10-20 23:28:31 (33.6 MB/s) - ‘CollegeScorecard_Raw_Data_09012022.zip’ saved [410294884/410294884]

# %% [markdown]
# ## Step 2 - Unzip the zip file

# %%
# !unzip CollegeScorecard_Raw_Data_09012022.zip
# Out:
# Archive:  CollegeScorecard_Raw_Data_09012022.zip
#  extracting: Crosswalks.zip
#   inflating: data.yaml
#   inflating: FieldOfStudyData1415_1516_PP.csv
#   inflating: FieldOfStudyData1516_1617_PP.csv
#   inflating: FieldOfStudyData1617_1718_PP.csv
#   inflating: FieldOfStudyData1718_1819_PP.csv
#   inflating: MERGED1996_97_PP.csv
#   inflating: MERGED1997_98_PP.csv
#   inflating: MERGED1998_99_PP.csv
#   inflating: MERGED1999_00_PP.csv
#   inflating: MERGED2000_01_PP.csv
#   inflating: MERGED2001_02_PP.csv
#   inflating: MERGED2002_03_PP.csv
#   inflating: MERGED2003_04_PP.csv
#   inflating: MERGED2004_05_PP.csv
#   inflating: MERGED2005_06_PP.csv
#   inflating: MERGED2006_07_PP.csv
#   inflating: MERGED2007_08_PP.csv
#   inflating: MERGED2008_09_PP.csv
#   inflating: MERGED2009_10_PP.csv
#   inflating: MERGED2010_11_PP.csv
#   inflating: MERGED2011_12_PP.csv
#   inflating: MERGED2012_13_PP.csv
#   inflating: MERGED2013_14_PP.csv
#   inflating: MERGED2014_15_PP.csv
#   inflating: MERGED2015_16_PP.csv
#   inflating: MERGED2016_17_PP.csv
#   inflating: MERGED2017_18_PP.csv
#   inflating: MERGED2018_19_PP.csv
#   inflating: MERGED2019_20_PP.csv
#   inflating: MERGED2020_21_PP.csv
#   inflating: Most-Recent-Cohorts-Field-of-Study.csv
#   inflating: Most-Recent-Cohorts-Institution.csv

# %% [markdown]
# ## Step 3 - Import Libraries

# %%
import pandas as pd
import os

# %%
import glob

# %%
import plotly.express as px

# %%
 import numpy as np

# %% [markdown]
# ## Step 4 - Display the current working directory using os.getcwd()
#
# You would need to import a standard Python library called os which stands for operating system. so place that import statement in the previous cell. Since your notebook and your data files may or may not in the same folder, you want to make sure what the current working folder is and how to access a data file in a different folder.

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ## Step 5 - Get the list of file names
#
# os library has a method call listdir which generates a list of files in a directory/folder. Use this method to assign the contents (list of file names) of the data folder to a variable and display it. If necessary, you can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

# %%
name_list = os.listdir()
name_list
# Out:
# ['.config',
#  'MERGED2018_19_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'data.yaml',
#  'Crosswalks.zip',
#  'CollegeScorecard_Raw_Data_09012022.zip',
#  'MERGED2008_09_PP.csv',
#  'FieldOfStudyData1718_1819_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'Most-Recent-Cohorts-Field-of-Study.csv',
#  'Most-Recent-Cohorts-Institution.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2020_21_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'FieldOfStudyData1617_1718_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2019_20_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'sample_data']

# %% [markdown]
# ## Step 6 - Process only the yearly data files
#
# The folder contains files that are not the yearly data files. Write code to remove the unwanted files from the list variable.
#
# Note: don't remove/delete these files from the folder in the folder.
# For example, use the file extension to only use the csv files or use the name patter - data file name begins with "MERGED". You can use the concept of list comprehension to write just *one* line of code as well as using a for loop, your choice.

# %%
yearly_list = [file_name for file_name in name_list if file_name.startswith("MERGED")]

yearly_list
# Out:
# ['MERGED2018_19_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2020_21_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2019_20_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2011_12_PP.csv']

# %% [markdown]
# ## Step 7 - Load data files
#
# Now that you have a clean list of the yearly files, you want to loop through them and read them into a dataframe one at a time. You only load six columns: ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
#
# You should use "usecols" option of Pandas to avoid reading unwanted columns. You also want to add a new column call "YEAR" to differentiate the data frames from each other. The YEAR variable should be yyyy format so tht you can convert them into integer. If you use the format yyyy-yy (such as 1997-98 school year), you will not be able to convert them directly to integer. If you use scatter plot, the YEAR needs to be converted to integer or float.
#
# You would use an empty list and append the yearly dataframes to the list. After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a new single data frame.
#
# Note: this exercise incorporates many techques we learned before:
#
# - list (creating an empty, append an item to the list)
# - for loop
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
#
# This exercise may appear challenging but it worths the effort. You will learn a lot and love it. I promise.

# %%
yearly_list.sort()

print("processing file", yearly_list[0])
df_all = pd.read_csv("/content/" + yearly_list[0], usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
df_all["year"] = yearly_list[0][6:10]
print(df_all.shape)

for yearly_file in yearly_list[1:]:
    print("processing file", yearly_file)
    df = pd.read_csv("/content/" + yearly_file, usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
    df["year"] = yearly_file[6:10]
    df_all = df_all.append(df, ignore_index = True)
    print(df_all.shape)
# Out:
# processing file MERGED1996_97_PP.csv
# (7007, 7)
# processing file MERGED1997_98_PP.csv
# (13941, 7)
# processing file MERGED1998_99_PP.csv
# (20643, 7)
# processing file MERGED1999_00_PP.csv
# (27252, 7)
# processing file MERGED2000_01_PP.csv
# (33906, 7)
# processing file MERGED2001_02_PP.csv
# (40631, 7)
# processing file MERGED2002_03_PP.csv
# (47283, 7)
# processing file MERGED2003_04_PP.csv
# (53956, 7)
# processing file MERGED2004_05_PP.csv
# (60703, 7)
# processing file MERGED2005_06_PP.csv
# (67602, 7)
# processing file MERGED2006_07_PP.csv
# (74553, 7)
# processing file MERGED2007_08_PP.csv
# (81524, 7)
# processing file MERGED2008_09_PP.csv
# (88579, 7)
# processing file MERGED2009_10_PP.csv
# (95796, 7)
# processing file MERGED2010_11_PP.csv
# (103266, 7)
# processing file MERGED2011_12_PP.csv
# (111012, 7)
# processing file MERGED2012_13_PP.csv
# (118874, 7)
# processing file MERGED2013_14_PP.csv
# (126743, 7)
# processing file MERGED2014_15_PP.csv
# (134509, 7)
# processing file MERGED2015_16_PP.csv
# (142175, 7)
# processing file MERGED2016_17_PP.csv
# (149413, 7)
# processing file MERGED2017_18_PP.csv
# (156525, 7)
# processing file MERGED2018_19_PP.csv
# (163332, 7)
# processing file MERGED2019_20_PP.csv
# (170026, 7)
# processing file MERGED2020_21_PP.csv
# (176707, 7)

# %%
df_all.sample(10)
# Out:
#           UNITID                                       INSTNM STABBR  REGION  \
# 10984     210234            Treasure Valley Community College     OR     8.0
# 170587    129428                       Rensselaer at Hartford     CT     1.0
# 164779    165529                                Curry College     MA     1.0
# 140700    457776  Toni & Guy Hairdressing Academy-Albuquerque     NM     6.0
# 103013  10236803                Troy University-Dothan Campus     AL     5.0
# 113303    182908                              Lebanon College     NH     1.0
# 147969    457642              Marketti Academy of Cosmetology     MI     3.0
# 126645  44376602        Strayer University-Shelby Oaks Campus     TN     5.0
# 2361      168290                             Wheelock College     MA     1.0
# 72720     378406             ITT Technical Institute-Torrance     CA     8.0
#
#         ADM_RATE  TUITIONFEE_IN  year
# 10984        NaN            NaN  1997
# 170587       NaN            NaN  2020
# 164779    0.8706        41230.0  2019
# 140700       NaN            NaN  2015
# 103013       NaN         5860.0  2010
# 113303       NaN         6998.0  2012
# 147969       NaN            NaN  2016
# 126645       NaN        15495.0  2013
# 2361         NaN            NaN  1996
# 72720     0.4981        14880.0  2006

# %% [markdown]
# ## Step 8 - Explore the new dataframe
#
# For example, # of observations, varibles, head, tail, sample, missing values, statistics, etc.

# %%
len(df_all)
# Out:
# 176707

# %%
df_all.shape
# Out:
# (176707, 7)

# %%
df_all.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL     0.0       NaN
# 1  100654                Alabama A & M University     AL     5.0       NaN
# 2  100663     University of Alabama at Birmingham     AL     5.0       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0       NaN
# 4  100690                      Amridge University     AL     5.0       NaN
#
#    TUITIONFEE_IN  year
# 0            NaN  1996
# 1            NaN  1996
# 2            NaN  1996
# 3            NaN  1996
# 4            NaN  1996

# %%
df_all.tail()
# Out:
#           UNITID                                             INSTNM STABBR  \
# 176702  49576719  Pennsylvania State University-Penn State Wilke...     PA
# 176703  49576720      Pennsylvania State University-Penn State York     PA
# 176704  49576721  Pennsylvania State University-Penn State Great...     PA
# 176705  49576722  Pennsylvania State University-Penn State Harri...     PA
# 176706  49576723  Pennsylvania State University-Penn State Brand...     PA
#
#         REGION  ADM_RATE  TUITIONFEE_IN  year
# 176702     2.0       NaN        13604.0  2020
# 176703     2.0       NaN        14486.0  2020
# 176704     2.0       NaN            NaN  2020
# 176705     2.0       NaN        15216.0  2020
# 176706     2.0       NaN        14486.0  2020

# %%
df_all.sample(5)
# Out:
#         UNITID                                       INSTNM STABBR  REGION  \
# 163921  130493        Southern Connecticut State University     CT     1.0
# 150730  157058                    Kentucky State University     KY     5.0
# 10425   197692                        Yeshiva Shaar Hatorah     NY     2.0
# 7673    123493  Charles A Jones Career and Education Center     CA     8.0
# 89985   154110             Northeast Iowa Community College     IA     4.0
#
#         ADM_RATE  TUITIONFEE_IN  year
# 163921    0.6936        11446.0  2019
# 150730    0.4528         8184.0  2017
# 10425        NaN            NaN  1997
# 7673         NaN            NaN  1997
# 89985        NaN         4576.0  2009

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176707 entries, 0 to 176706
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   UNITID         176707 non-null  int64
#  1   INSTNM         176707 non-null  object
#  2   STABBR         176707 non-null  object
#  3   REGION         176706 non-null  float64
#  4   ADM_RATE       48863 non-null   float64
#  5   TUITIONFEE_IN  86867 non-null   float64
#  6   year           176707 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 9.4+ MB

# %%
df_all.isnull()
# Out:
#         UNITID  INSTNM  STABBR  REGION  ADM_RATE  TUITIONFEE_IN   year
# 0        False   False   False   False      True           True  False
# 1        False   False   False   False      True           True  False
# 2        False   False   False   False      True           True  False
# 3        False   False   False   False      True           True  False
# 4        False   False   False   False      True           True  False
# ...        ...     ...     ...     ...       ...            ...    ...
# 176702   False   False   False   False      True          False  False
# 176703   False   False   False   False      True          False  False
# 176704   False   False   False   False      True           True  False
# 176705   False   False   False   False      True          False  False
# 176706   False   False   False   False      True          False  False
#
# [176707 rows x 7 columns]

# %%
df_all.describe()
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN
# count  1.767070e+05  176706.000000  48863.000000   86867.000000
# mean   1.054338e+06       4.559279      0.693785   12037.588290
# std    4.959072e+06       2.188341      0.217019   10462.970227
# min    1.006360e+05       0.000000      0.000000       0.000000
# 25%    1.641730e+05       3.000000      0.556700    3936.000000
# 50%    2.136310e+05       5.000000      0.719500    9422.000000
# 75%    4.137780e+05       6.000000      0.857100   16490.000000
# max    4.957672e+07       9.000000      1.000000   74787.000000

# %% [markdown]
# ## Step 9 - UMBC
#
# The dataframe contains many years of data of all U.S. colleges. let's just look at UMBC. Filter/query the dataframe to retrieve only rows that belong to UMBC (one row represent one year). Save the UMNC data to a new data frame. using a new variable for the UMBC data frame, so that the old big data frame is still available for later use.

# %%
df1=df_all.loc[df_all['INSTNM'] == "University of Maryland-Baltimore County"]  # searching for umbc
df1
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 104960  163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  year
# 2151         NaN            NaN  1996
# 9056         NaN            NaN  1997
# 15923        NaN            NaN  1998
# 22598        NaN            NaN  1999
# 29178        NaN         5490.0  2000
# 35821     0.6551         5910.0  2001
# 42524     0.6327         6362.0  2002
# 49156     0.5757         7388.0  2003
# 55786     0.7014         8020.0  2004
# 62522     0.7143         8520.0  2005
# 69401     0.7153         8622.0  2006
# 76332     0.6895         8708.0  2007
# 83291     0.7174         8780.0  2008
# 90324     0.6890         8872.0  2009
# 97506     0.6589         9171.0  2010
# 104960    0.6081         9467.0  2011
# 112672    0.6035         9764.0  2012
# 120503    0.6315        10068.0  2013
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018
# 164723    0.6103        12028.0  2019
# 171401    0.6948         9420.0  2020

# %% [markdown]
# ## Step 10 - Explore the new dataframe
#
# For example, # of observations, varibles, head, tail, sample, missing values, statistics, etc

# %%
df1.shape
# Out:
# (25, 7)

# %%
df1.head()
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 9056   163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
# 22598  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  year
# 2151        NaN            NaN  1996
# 9056        NaN            NaN  1997
# 15923       NaN            NaN  1998
# 22598       NaN            NaN  1999
# 29178       NaN         5490.0  2000

# %%
df1.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  year
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018
# 164723    0.6103        12028.0  2019
# 171401    0.6948         9420.0  2020

# %%
df1.sample(5)
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  year
# 83291     0.7174         8780.0  2008
# 22598        NaN            NaN  1999
# 49156     0.5757         7388.0  2003
# 128353    0.5961        10384.0  2014
# 76332     0.6895         8708.0  2007

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 2151 to 171401
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UNITID         25 non-null     int64
#  1   INSTNM         25 non-null     object
#  2   STABBR         25 non-null     object
#  3   REGION         25 non-null     float64
#  4   ADM_RATE       20 non-null     float64
#  5   TUITIONFEE_IN  21 non-null     float64
#  6   year           25 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
df1.isnull()
# Out:
#         UNITID  INSTNM  STABBR  REGION  ADM_RATE  TUITIONFEE_IN   year
# 2151     False   False   False   False      True           True  False
# 9056     False   False   False   False      True           True  False
# 15923    False   False   False   False      True           True  False
# 22598    False   False   False   False      True           True  False
# 29178    False   False   False   False      True          False  False
# 35821    False   False   False   False     False          False  False
# 42524    False   False   False   False     False          False  False
# 49156    False   False   False   False     False          False  False
# 55786    False   False   False   False     False          False  False
# 62522    False   False   False   False     False          False  False
# 69401    False   False   False   False     False          False  False
# 76332    False   False   False   False     False          False  False
# 83291    False   False   False   False     False          False  False
# 90324    False   False   False   False     False          False  False
# 97506    False   False   False   False     False          False  False
# 104960   False   False   False   False     False          False  False
# 112672   False   False   False   False     False          False  False
# 120503   False   False   False   False     False          False  False
# 128353   False   False   False   False     False          False  False
# 136064   False   False   False   False     False          False  False
# 143685   False   False   False   False     False          False  False
# 150891   False   False   False   False     False          False  False
# 157940   False   False   False   False     False          False  False
# 164723   False   False   False   False     False          False  False
# 171401   False   False   False   False     False          False  False

# %%
df1.describe()   #for statistics of the dataframe we use describe
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN
# count      25.0    25.0  20.000000      21.000000
# mean   163268.0     2.0   0.641880    9168.571429
# std         0.0     0.0   0.051853    1854.082079
# min    163268.0     2.0   0.568300    5490.000000
# 25%    163268.0     2.0   0.600600    8520.000000
# 50%    163268.0     2.0   0.632100    9171.000000
# 75%    163268.0     2.0   0.690825   10384.000000
# max    163268.0     2.0   0.717400   12028.000000

# %% [markdown]
# ## Step 11 - Plot UMBC's in-state tution overtime Bar Chart

# %%
color_discrete_sequence = ['#ec7c34']*len(df)
color_discrete_sequence[5] = '#609cd4'
fig = px.bar(df1, x='TUITIONFEE_IN', y='year',color_discrete_sequence=color_discrete_sequence)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9bcb8b07-309e-49f8-a1d3-8d1352f09c37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bcb8b07-309e-49f8-a1d3-8d1352f09c37")) {                    Plotly.newPlot(                        "9bcb8b07-309e-49f8-a1d3-8d1352f09c37",                        [{"alignmentgroup":"True","hovertemplate":"TUITIONFEE_IN=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#ec7c34","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[null,null,null,null,5490.0,5910.0,6362.0,7388.0,8020.0,8520.0,8622.0,8708.0,8780.0,8872.0,9171.0,9467.0,9764.0,10068.0,10384.0,11006.0,11264.0,11518.0,11778.0,12028.0,9420.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"c ...

# %% [markdown]
# ## Step 12 - Plot UMBC's in-state tution overtime using line Chart

# %%
fig = px.line(df1, x="TUITIONFEE_IN", y="year", title='UMBC in-state tution overtime')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f3c44049-cb92-409b-8d1a-7bf56b2fffae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3c44049-cb92-409b-8d1a-7bf56b2fffae")) {                    Plotly.newPlot(                        "f3c44049-cb92-409b-8d1a-7bf56b2fffae",                        [{"hovertemplate":"TUITIONFEE_IN=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[null,null,null,null,5490.0,5910.0,6362.0,7388.0,8020.0,8520.0,8622.0,8708.0,8780.0,8872.0,9171.0,9467.0,9764.0,10068.0,10384.0,11006.0,11264.0,11518.0,11778.0,12028.0,9420.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth": ...

# %% [markdown]
# ## Step 13 - Tuition Growth Rate
#
# Now let's look at the tuition growth rate year over year. We need to calculate UMBC tuition change percentage each year. First convert the TUITIONFEE_IN column to a Python List

# %%
# Using Series.values.tolist()
TUITIONFEE_IN_list = df1.TUITIONFEE_IN.tolist()
print(TUITIONFEE_IN_list)
# Out:
# [nan, nan, nan, nan, 5490.0, 5910.0, 6362.0, 7388.0, 8020.0, 8520.0, 8622.0, 8708.0, 8780.0, 8872.0, 9171.0, 9467.0, 9764.0, 10068.0, 10384.0, 11006.0, 11264.0, 11518.0, 11778.0, 12028.0, 9420.0]

# %%
len(TUITIONFEE_IN_list)
# Out:
# 25

# %% [markdown]
# ## Step 14 - Loop through the list and calculate the % change each year over the prior year
#
# This takes some effort. Not hard, just some abstract/logical thinking and some experiments. Have fun on this one.

# %%
a = np.array(TUITIONFEE_IN_list, dtype=float)
per_change=np.diff(a) / a[:-1] * 100.
per_change
# Out:
# array([         nan,          nan,          nan,          nan,
#          7.65027322,   7.64805415,  16.12700409,   8.55441256,
#          6.23441397,   1.1971831 ,   0.99744839,   0.82682591,
#          1.04783599,   3.37015329,   3.22756515,   3.13721348,
#          3.11347808,   3.13865713,   5.98998459,   2.3441759 ,
#          2.25497159,   2.25733634,   2.12260146, -21.68274027])

# %% [markdown]
# ## Step 15 - Round up the percentage to two decimal points
#
# The resulting number has many decimal points which are unnecessary and not visually appealing. You can use for loop. Or better, use list comprehension for simplicity/brevity.

# %%
rounded_list = [round(item, 2) for item in per_change]
print(rounded_list)
# Out:
# [nan, nan, nan, nan, 7.65, 7.65, 16.13, 8.55, 6.23, 1.2, 1.0, 0.83, 1.05, 3.37, 3.23, 3.14, 3.11, 3.14, 5.99, 2.34, 2.25, 2.26, 2.12, -21.68]

# %%
len(rounded_list)
# Out:
# 24

# %%
rounded_list.append(0)
len(rounded_list)
# Out:
# 25

# %% [markdown]
# ## Step 16 - Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
#
# Not as hard as you may think. If you get stuck, you think too hard. Google it and you will find the answer.

# %%
df1["percent_change_tution"] = rounded_list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 104960  163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  year  percent_change_tution
# 2151         NaN            NaN  1996                    NaN
# 9056         NaN            NaN  1997                    NaN
# 15923        NaN            NaN  1998                    NaN
# 22598        NaN            NaN  1999                    NaN
# 29178        NaN         5490.0  2000                   7.65
# 35821     0.6551         5910.0  2001                   7.65
# 42524     0.6327         6362.0  2002                  16.13
# 49156     0.5757         7388.0  2003                   8.55
# 55786     0.7014         8020.0  2004                   6.23
# 62522     0.7143         8520.0  2005                   1.20
# 69401     0.7153         8622.0  2006                   1.00
# 76332     0.6895         8708.0  2007                   0.83
# 83291     0.7174         8780.0  2008                   1.05
# 90324     0.6890         8872.0  2009                   3.37
# 97506     0.6589         9171.0  2010                   3.23
# 104960    0.6081         9467.0  2011                   3.14
# 112672    0.6035         9764.0  2012                   3.11
# 120503    0.6315        10068.0  2013                   3.14
# 128353    0.5961        10384.0  2014                   5.99
# 136064    0.5942        11006.0  2015                   2.34
# 143685    0.5683        11264.0  2016                   2.25
# 150891    0.6021        11518.0  2017                   2.26
# 157940    0.5794        11778.0  2018                   2.12
# 164723    0.6103        12028.0  2019                 -21.68
# 171401    0.6948         9420.0  2020                   0.00

# %% [markdown]
# ## Step 17 - Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

# %%
fig = px.bar(df1, x='percent_change_tution', y='year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c82e3783-a15c-4cde-ae5d-d8ab6737b88a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c82e3783-a15c-4cde-ae5d-d8ab6737b88a")) {                    Plotly.newPlot(                        "c82e3783-a15c-4cde-ae5d-d8ab6737b88a",                        [{"alignmentgroup":"True","hovertemplate":"percent_change_tution=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[null,null,null,null,7.65,7.65,16.13,8.55,6.23,1.2,1.0,0.83,1.05,3.37,3.23,3.14,3.11,3.14,5.99,2.34,2.25,2.26,2.12,-21.68,0.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"t ...

# %%
fig = px.line(df1, x="percent_change_tution", y="year", title='UMBC in-state percent_change_tution over year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0da00fe4-7949-4454-8cdc-eca452e3d7f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0da00fe4-7949-4454-8cdc-eca452e3d7f4")) {                    Plotly.newPlot(                        "0da00fe4-7949-4454-8cdc-eca452e3d7f4",                        [{"hovertemplate":"percent_change_tution=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[null,null,null,null,7.65,7.65,16.13,8.55,6.23,1.2,1.0,0.83,1.05,3.37,3.23,3.14,3.11,3.14,5.99,2.34,2.25,2.26,2.12,-21.68,0.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoord ...

# %% [markdown]
# ## Step 18 - Define Growth Rate Function
#
# Since we want to do the same calculation for JHU. Instead of doing it piecemeal as we did for UMBC. Let's create a function which can be reused for any college. This function takes a list of tuitions and return a list of percentage changes year over year. This function can be used later.

# %%
def growth_rate(tutionlist):
   a = np.array(TUITIONFEE_IN_list, dtype=float)
   per_change=np.diff(a) / a[:-1] * 100.
   rounded_list = [round(item, 2) for item in per_change]
   rounded_list.append(0)
   return rounded_list

# %%
TUITIONFEE_IN_list = df1.TUITIONFEE_IN.tolist()

print(growth_rate(TUITIONFEE_IN_list))
# Out:
# [nan, nan, nan, nan, 7.65, 7.65, 16.13, 8.55, 6.23, 1.2, 1.0, 0.83, 1.05, 3.37, 3.23, 3.14, 3.11, 3.14, 5.99, 2.34, 2.25, 2.26, 2.12, -21.68, 0]

# %% [markdown]
# ## Step 19 - Get JHU Data
#
# The dataframe contains many years of data of all U.S. colleges. Let's just look at JHU. Filter/query the dataframe to retrieve only rows that belong to JHU. Save the JHU data to a new data frame using a new variable so that the old big data frame is still available for later use.

# %%
df2=df_all.loc[df_all['INSTNM'] == "Johns Hopkins University"]  
df2
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# 90317   162928  Johns Hopkins University     MD     2.0    0.2782
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 104953  162928  Johns Hopkins University     MD     2.0    0.1940
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
# 164718  162928  Johns Hopkins University     MD     2.0    0.1117
# 171396  162928  Johns Hopkins University     MD     2.0    0.1106
#
#         TUITIONFEE_IN  year
# 2139              NaN  1996
# 9046              NaN  1997
# 15914             NaN  1998
# 22589             NaN  1999
# 29169         24930.0  2000
# 35812         26210.0  2001
# 42515         27390.0  2002
# 49148         28730.0  2003
# 55779         30140.0  2004
# 62515         31620.0  2005
# 69394         33900.0  2006
# 76325         35900.0  2007
# 83284         37700.0  2008
# 90317         39150.0  2009
# 97499         40680.0  2010
# 104953        42280.0  2011
# 112665        43390.0  2012
# 120496        45470.0  2013
# 128346        47060.0  2014
# 136057        48710.0  2015
# 143678        50410.0  2016
# 150886        52170.0  2017
# 157935        53740.0  2018
# 164718        55350.0  2019
# 171396        54160.0  2020

# %% [markdown]
# ## Step 20 - Plot JHU's in-state tuition overtime
#
# Let's plot bar and then line chart.

# %%
# <14> 
# Plot JHU's in-state tuition overtime from 1996 to 2019. 
# Let's plot bar and line chart together

#(Write code here)
df3=df2.loc[df2['year'] != "2020"]  
df3
fig = px.bar(df3, x='TUITIONFEE_IN', y='year')
fig.show()

fig = px.line(df3, x="TUITIONFEE_IN", y="year", title='UMBC in-state tution overtime')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0862af13-afb0-4c1f-be23-914207fd62e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0862af13-afb0-4c1f-be23-914207fd62e4")) {                    Plotly.newPlot(                        "0862af13-afb0-4c1f-be23-914207fd62e4",                        [{"alignmentgroup":"True","hovertemplate":"TUITIONFEE_IN=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[null,null,null,null,24930.0,26210.0,27390.0,28730.0,30140.0,31620.0,33900.0,35900.0,37700.0,39150.0,40680.0,42280.0,43390.0,45470.0,47060.0,48710.0,50410.0,52170.0,53740.0,55350.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"co ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0736b45f-28c9-481f-81b8-b312f672625d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0736b45f-28c9-481f-81b8-b312f672625d")) {                    Plotly.newPlot(                        "0736b45f-28c9-481f-81b8-b312f672625d",                        [{"hovertemplate":"TUITIONFEE_IN=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[null,null,null,null,24930.0,26210.0,27390.0,28730.0,30140.0,31620.0,33900.0,35900.0,37700.0,39150.0,40680.0,42280.0,43390.0,45470.0,47060.0,48710.0,50410.0,52170.0,53740.0,55350.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ## Step 21 - Calculate Tuition Growth Rate using the Function defined earlier

# %%
TUITIONFEE_IN_list = df2.TUITIONFEE_IN.tolist()
print(TUITIONFEE_IN_list)
x=growth_rate(TUITIONFEE_IN_list)
print(x)
# Out:
# [nan, nan, nan, nan, 24930.0, 26210.0, 27390.0, 28730.0, 30140.0, 31620.0, 33900.0, 35900.0, 37700.0, 39150.0, 40680.0, 42280.0, 43390.0, 45470.0, 47060.0, 48710.0, 50410.0, 52170.0, 53740.0, 55350.0, 54160.0]
# [nan, nan, nan, nan, 5.13, 4.5, 4.89, 4.91, 4.91, 7.21, 5.9, 5.01, 3.85, 3.91, 3.93, 2.63, 4.79, 3.5, 3.51, 3.49, 3.49, 3.01, 3.0, -2.15, 0]

# %% [markdown]
# ## Step 22 - Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

# %%
df2["percent_change_tution"] = x
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# 90317   162928  Johns Hopkins University     MD     2.0    0.2782
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 104953  162928  Johns Hopkins University     MD     2.0    0.1940
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
# 164718  162928  Johns Hopkins University     MD     2.0    0.1117
# 171396  162928  Johns Hopkins University     MD     2.0    0.1106
#
#         TUITIONFEE_IN  year  percent_change_tution
# 2139              NaN  1996                    NaN
# 9046              NaN  1997                    NaN
# 15914             NaN  1998                    NaN
# 22589             NaN  1999                    NaN
# 29169         24930.0  2000                   5.13
# 35812         26210.0  2001                   4.50
# 42515         27390.0  2002                   4.89
# 49148         28730.0  2003                   4.91
# 55779         30140.0  2004                   4.91
# 62515         31620.0  2005                   7.21
# 69394         33900.0  2006                   5.90
# 76325         35900.0  2007                   5.01
# 83284         37700.0  2008                   3.85
# 90317         39150.0  2009                   3.91
# 97499         40680.0  2010                   3.93
# 104953        42280.0  2011                   2.63
# 112665        43390.0  2012                   4.79
# 120496        45470.0  2013                   3.50
# 128346        47060.0  2014                   3.51
# 136057        48710.0  2015                   3.49
# 143678        50410.0  2016                   3.49
# 150886        52170.0  2017                   3.01
# 157935        53740.0  2018                   3.00
# 164718        55350.0  2019                  -2.15
# 171396        54160.0  2020                   0.00

# %% [markdown]
# ## Step 23 - Plot the JHU percentage changes tuitions over time
#
# Bar plot first, then line plot.

# %%
fig = px.bar(df2, x='percent_change_tution', y='year')
fig.show()

fig = px.line(df2, x="percent_change_tution", y="year", title='jhu percent_change_tution overtime')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b3aa84fe-2b7d-477b-b76c-8dacf18f8cb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3aa84fe-2b7d-477b-b76c-8dacf18f8cb0")) {                    Plotly.newPlot(                        "b3aa84fe-2b7d-477b-b76c-8dacf18f8cb0",                        [{"alignmentgroup":"True","hovertemplate":"percent_change_tution=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[null,null,null,null,5.13,4.5,4.89,4.91,4.91,7.21,5.9,5.01,3.85,3.91,3.93,2.63,4.79,3.5,3.51,3.49,3.49,3.01,3.0,-2.15,0.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2e7543e6-7da9-4cd7-8c62-a7faf75ae9be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e7543e6-7da9-4cd7-8c62-a7faf75ae9be")) {                    Plotly.newPlot(                        "2e7543e6-7da9-4cd7-8c62-a7faf75ae9be",                        [{"hovertemplate":"percent_change_tution=%{x}<br>year=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[null,null,null,null,5.13,4.5,4.89,4.91,4.91,7.21,5.9,5.01,3.85,3.91,3.93,2.63,4.79,3.5,3.51,3.49,3.49,3.01,3.0,-2.15,0.0],"xaxis":"x","y":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[ ...

# %% [markdown]
# ## Step 24 - Compare UMBC and JHU
#
# In order to plot both UMBC and JHU tuition change over time in the same plot, we need to combine the two datasets using the common key of YEAR.
#
# First make a umbc2 dataframe with only two columns needed. We don't need other columns. Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge. This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE", we rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully, Feel free to try it without changing the column names.

# %%
umbc2 = df1[['percent_change_tution', 'year']]
umbc2.rename(columns = {'percent_change_tution': 'UMBC_PCT'}, inplace=True)
umbc2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        UMBC_PCT  year
# 2151        NaN  1996
# 9056        NaN  1997
# 15923       NaN  1998
# 22598       NaN  1999
# 29178      7.65  2000

# %% [markdown]
# ## Step 25
#
# Then make a jhu2 dataframe with only two columns needed. WE don't need other columns. Also change the column name from "PCT_CHANGE" to "JHU_PCT"  in preparation for the merge

# %%
jhu2= df2[['percent_change_tution', 'year']]
jhu2.rename(columns = {'percent_change_tution': 'JHU_PCT'}, inplace=True)
jhu2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        JHU_PCT  year
# 2139       NaN  1996
# 9046       NaN  1997
# 15914      NaN  1998
# 22589      NaN  1999
# 29169     5.13  2000

# %% [markdown]
# ## Step 26 - Merger the two data frames and display the new dataframe

# %%
df4=pd.merge(umbc2, jhu2, left_on='year', right_on='year', how='inner')
df4
# Out:
#     UMBC_PCT  year  JHU_PCT
# 0        NaN  1996      NaN
# 1        NaN  1997      NaN
# 2        NaN  1998      NaN
# 3        NaN  1999      NaN
# 4       7.65  2000     5.13
# 5       7.65  2001     4.50
# 6      16.13  2002     4.89
# 7       8.55  2003     4.91
# 8       6.23  2004     4.91
# 9       1.20  2005     7.21
# 10      1.00  2006     5.90
# 11      0.83  2007     5.01
# 12      1.05  2008     3.85
# 13      3.37  2009     3.91
# 14      3.23  2010     3.93
# 15      3.14  2011     2.63
# 16      3.11  2012     4.79
# 17      3.14  2013     3.50
# 18      5.99  2014     3.51
# 19      2.34  2015     3.49
# 20      2.25  2016     3.49
# 21      2.26  2017     3.01
# 22      2.12  2018     3.00
# 23    -21.68  2019    -2.15
# 24      0.00  2020     0.00

# %% [markdown]
# ## Step 27 - Plot UMBC and JHU separately on the same line plot

# %%
fig = px.line(df4, x='year', y=['JHU_PCT', 'UMBC_PCT'], title='comparision of jhu and umbc')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1af48633-d12a-49a9-947e-15ca8fa16748" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1af48633-d12a-49a9-947e-15ca8fa16748")) {                    Plotly.newPlot(                        "1af48633-d12a-49a9-947e-15ca8fa16748",                        [{"hovertemplate":"variable=JHU_PCT<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"JHU_PCT","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"JHU_PCT","orientation":"v","showlegend":true,"x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[null,null,null,null,5.13,4.5,4.89,4.91,4.91,7.21,5.9,5.01,3.85,3.91,3.93,2.63,4.79,3.5,3.51,3.49,3.49,3.01,3.0,-2.15,0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=UMBC_PCT<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"UMBC_PCT","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"UMBC_PCT","orientation":"v","showlegend":true,"x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[null,null,null,null,7.65,7.65,16.13,8.55,6.23,1.2,1.0,0.83,1.05,3.37,3.23,3.14,3.11,3.14,5.99,2.34,2.25,2.26,2.12,-21.68,0.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556," ...

# %% [markdown]
# ## Step 28 - Document your observation of the comparison plots using the following Markdown cell

# %% [markdown]
# #### According to my analysis of the line graph above, the pace of umbc's tuition growth is significantly increased from 2001 to 2003 before declining. Both plots show a consistent growth rate between 2003 and 2018, although generally, Jhu's in-state tuition growth rate is higher than UMBC's.

# %% [markdown]
# REF:
# 1.https://realpython.com/pandas-python-explore-dataset/
#
# 2.https://sparkbyexamples.com/pandas/conver-pandas-column-to-list/#:~:text=tolist()%20you%20can%20convert,the%20column%20values%20to%20list.
#
# 3.https://stackoverflow.com/questions/10226551/whats-the-most-pythonic-way-to-calculate-percentage-changes-on-a-list-of-numbers
